# %% [markdown]
# # Exploratody data analysis

# %%
import os 
import sys
import glob
import pickle
import pyprind
import pandas as pd
pd.set_option('display.max_rows', 300)
pd.set_option('display.max_columns', 300)

import numpy as np
from sklearn.manifold import TSNE
from sklearn.decomposition import TruncatedSVD

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

import warnings
warnings.filterwarnings('ignore')

import utils
import data_prep as prep
import train_select as ts

# %%
random_state = 42

# %%
npi = prep.prepare_npi(prep.npi_url, dropna=True, add_new_features=True, verbose=True)
# Out:
# INFO Data set PartD_Prescriber_PUF_NPI_15.zip
# INFO from url: http://download.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/Medicare-Provider-Charge-Data/Downloads/PartD_Prescriber_PUF_NPI_15.zip
# INFO successfully downloaded and uncompressed
# INFO Data cleaning completed
# INFO New features are added

# %% [markdown]
# # Descriptive statistics
# #### 1. op_prescriber

# %%
npi.op_prescriber.value_counts()
# Out:
# True     438183
# False    192807
# Name: op_prescriber, dtype: int64

# %% [markdown]
# #### 2. Average days op_prescribed if  opioid was prescribed

# %%
npi['avg_op_day_supply'].describe()
# Out:
# count    630990.000000
# mean         33.536462
# std          52.416996
# min           0.000000
# 25%           0.000000
# 50%           6.406250
# 75%          51.730509
# max         695.891566
# Name: avg_op_day_supply, dtype: float64

# %% [markdown]
# #### 3. op_longer

# %%
npi.op_longer.value_counts()
# Out:
# False    533997
# True      96993
# Name: op_longer, dtype: int64

# %%
ntl, drug_name_dict = prep.get_drug_name_dict(threshold=500)
non_op_names, op_names = prep.get_drug_names(ntl, drug_name_dict, 
                                        n_other_drugs=prep.n_other_drugs, 
                                        random_state=random_state)
# Out:
# INFO Data set PartD_Prescriber_PUF_Drug_Ntl_15.zip
# INFO from url: http://download.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/Medicare-Provider-Charge-Data/Downloads/PartD_Prescriber_PUF_Drug_Ntl_15.zip
# INFO successfully downloaded and uncompressed

# %%
for k in drug_name_dict.keys():
    print("{}: {}".format(k, len(drug_name_dict[k])))
# Out:
# High Risk Medication (HRM) Drug Flag: 68
# Antipsychotic Drug Flag: 28
# Antibiotic Drug Flag: 78
# others: 951
# Opioid Drug Flag: 29

# %% [markdown]
# ## Make small dataset for EDA

# %%
drugs = prep.download_drugs()
# Out:
# INFO Data set PartD_Prescriber_PUF_NPI_DRUG_15.zip
# INFO from url: http://download.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/Medicare-Provider-Charge-Data/Downloads/PartD_Prescriber_PUF_NPI_DRUG_15.zip
# INFO successfully downloaded and uncompressed

# %% [markdown]
# We'll use batches 0 through 5, except batch 0 and 2 (which are included in the test set), for exploratory data analysis.

# %%
chunk_size = prep.chunk_size  # 100,000
eda_df = None
batch_to_pass = [0, 2]
for i in range(5):
    if i in batch_to_pass: 
        pass
    
    else:
        tmp_df = prep.clean_drug_chunks(drugs, npi, non_op_names, op_names, scale=False, chunk_size=chunk_size)
        if eda_df is None:
            eda_df = tmp_df
        else:
            eda_df = pd.concat([eda_df, tmp_df])

# %%
print(eda_df.shape)
#list(eda_df.columns)
# Out:
# (17703, 455)

# %%
with open('dataset/eda.pickle', 'wb') as f:
    pickle.dump(eda_df, f)
    f.close()

# %% [markdown]
# # Specialty vs avg day of opioid supply

# %%
npi_op = npi.loc[:, ['op_day_supply', 'avg_op_day_supply']]
df = eda_df.join(npi_op, how='inner')

# %%
tmp = df['avg_op_day_supply'].groupby(df['specialty']).describe().unstack()
misc = tmp.loc[tmp['count'] < 10, :].index
df = df.loc[~df['specialty'].isin(misc), :]
grouped_spec = df['avg_op_day_supply'].groupby(df['specialty'])
grouped_spec_mean = grouped_spec.mean().sort_values(ascending=False)
top20 = grouped_spec_mean.index[:20]
top40 = grouped_spec_mean.index[:40]
top63 = grouped_spec_mean.index[:63]

# %%
total_spec = df['op_day_supply'].groupby(df['specialty']).sum().sort_values(ascending=False)
#total_spec / total_spec.sum()

# %% [markdown]
# #### pandas

# %%
#eda_df.boxplot('avg_op_day_supply', by='specialty')

# %% [markdown]
# #### plotly

# %%
import plotly.plotly as py
import plotly.graph_objs as go
    
data = []
for name, group in grouped_spec:
    if name in top20:
        trace = go.Box(x=group, name=name)
        data.append(trace)
    
#py.iplot(data)

# %% [markdown]
# #### seaborn

# %%
sns.set(style='whitegrid', rc={"figure.figsize": (12, 16)})
df_small = df.loc[:, ['specialty', 'avg_op_day_supply']]
df_small = df_small.loc[df['specialty'].isin(top63), :]
sns.boxplot(data=df_small, y='specialty', x='avg_op_day_supply', order=top63)
plt.show()

# %%
tmp = df_small.groupby(df_small['specialty']).describe().unstack()
tmp.loc[top40, ]
# Out:
#                                                    avg_op_day_supply  \
#                                                                count
# specialty
# interventional_pain_management                                  52.0
# pain_management                                                 63.0
# anesthesiology                                                 100.0
# rheumatology                                                   142.0
# physical_medicine_and_rehabilitation                           180.0
# family_practice                                               2490.0
# general_practice                                               154.0
# osteopathic_manipulative_medicine                               14.0
# neurology                                                      231.0
# geriatric_medicine                                              57.0
# hematology_oncology                                            248.0
# medical_oncology                                                97.0
# internal_medicine                                             3390.0
# pediatric_medicine                                              31.0
# sports_medicine                                                 13.0
# nephrology                                                     208.0
# nurse_practitioner                                            1683.0
# specialist                                                      18.0
# infectious_disease                                              50.0
# radiation_oncology                                              44.0
# neurosurgery                                                   107.0
# orthopaedic_surgery                                             23.0
# physician_assistant                                           1325.0
# diagnostic_radiology                                            17.0
# critical_care_(intensivists)                                    19.0
# orthopedic_surgery                                             475.0
# pulmonary_disease                                              156.0
# registered_nurse                                                10.0
# certified_clinical_nurse_specialist                             25.0
# cardiology                                                     359.0
# gynecological_oncology                                          20.0
# podiatry                                                       229.0
# gastroenterology                                               150.0
# surgical_oncology                                               11.0
# colorectal_surgery_(formerly_proctology)                        32.0
# student_in_an_organized_health_care_education_t...             279.0
# cardiac_surgery                                                 23.0
# vascular_surgery                                                78.0
# interventional_cardiology                                       29.0
# allergy_immunology                                              69.0
#
#                                                                             \
#                                                           mean         std
# specialty
# interventional_pain_management                      159.498497   88.546691
# pain_management                                     152.287182   88.113950
# anesthesiology                                      141.104424  100.876735
# rheumatology                                        109.699515   47.244579
# physical_medicine_and_rehabilitation                109.074485  106.777851
# family_practice                                      77.651604   54.746292
# general_practice                                     77.390146   63.401477
# osteopathic_manipulative_medicine                    75.701182   43.593904
# neurology                                            75.262453   78.097238
# geriatric_medicine                                   71.870558   45.871218
# hematology_oncology                                  71.402983   33.557560
# medical_oncology                                     63.337603   30.916972
# internal_medicine                                    62.755186   55.611973
# pediatric_medicine                                   58.254542   62.982040
# sports_medicine                                      50.333643   92.306689
# nephrology                                           47.424384   45.424080
# nurse_practitioner                                   35.722199   49.237030
# specialist                                           32.387506   63.833871
# infectious_disease                                   31.509781   62.052816
# radiation_oncology                                   31.339090   14.222398
# neurosurgery                                         29.520978   23.503282
# orthopaedic_surgery                                  29.115704   40.102261
# physician_assistant                                  28.368205   41.699628
# diagnostic_radiology                                 23.953820   50.202667
# critical_care_(intensivists)                         23.695571   33.267881
# orthopedic_surgery                                   23.585800   25.838525
# pulmonary_disease                                    22.805692   37.649318
# registered_nurse                                     22.799217   26.485407
# certified_clinical_nurse_specialist                  20.486699   47.851542
# cardiology                                           20.339646   34.836757
# gynecological_oncology                               17.336404   15.461324
# podiatry                                             15.464764   18.486602
# gastroenterology                                     14.954526   37.154499
# surgical_oncology                                    13.053065   16.299724
# colorectal_surgery_(formerly_proctology)             12.435822    8.377534
# student_in_an_organized_health_care_education_t...   12.267240   20.101585
# cardiac_surgery                                      11.775395   11.684224
# vascular_surgery                                     11.617397    9.491192
# interventional_cardiology                            11.048858   27.708998
# allergy_immunology                                   10.731008   52.631870
#
#                                                                            \
#                                                           min         25%
# specialty
# interventional_pain_management                       5.960265  103.316008
# pain_management                                     22.687500   83.390384
# anesthesiology                                      16.500000   70.611807
# rheumatology                                         0.000000   80.082690
# physical_medicine_and_rehabilitation                 0.000000   28.751736
# family_practice                                      0.000000   35.197115
# general_practice                                     0.000000   30.636806
# osteopathic_manipulative_medicine                   28.752688   36.738197
# neurology                                            0.000000    0.000000
# geriatric_medicine                                   0.000000   36.833333
# hematology_oncology                                 21.272727   46.941707
# medical_oncology                                     0.000000   42.681818
# internal_medicine                                    0.000000    9.938419
# pediatric_medicine                                   0.000000    1.303571
# sports_medicine                                      6.720000   10.500000
# nephrology                                           0.000000    6.336538
# nurse_practitioner                                   0.000000    0.000000
# specialist                                           0.000000    0.000000
# infectious_disease                                   0.000000    0.000000
# radiation_oncology                                  14.083333   21.204963
# neurosurgery                                         0.000000   16.412830
# orthopaedic_surgery                                  0.000000   10.379032
# physician_assistant                                  0.000000    3.113636
# diagnostic_radiology                                 0.000000    0.000000
# critical_care_(intensivists)                         0.000000    0.000000
# orthopedic_surgery                                   3.486486   12.048909
# pulmonary_disease                                    0.000000    0.000000
# registered_nurse                                     0.000000    0.000000
# certified_clinical_nurse_specialist                  0.000000    0.000000
# cardiology                                           0.000000    0.000000
# gynecological_oncology                               0.000000    8.995581
# podiatry                                             0.000000    5.258065
# gastroenterology                                     0.000000    0.000000
# surgical_oncology                                    3.550000    6.028021
# colorectal_surgery_(formerly_proctology)             0.000000    7.634680
# student_in_an_organized_health_care_education_t...   0.000000    2.197619
# cardiac_surgery                                      0.000000    6.068966
# vascular_surgery                                     0.000000    6.360294
# interventional_cardiology                            0.000000    0.000000
# allergy_immunology                                   0.000000    0.000000
#
#                                                                             \
#                                                            50%         75%
# specialty
# interventional_pain_management                      143.013031  211.591820
# pain_management                                     140.946360  199.470743
# anesthesiology                                      110.926219  184.505023
# rheumatology                                        105.465774  138.393617
# physical_medicine_and_rehabilitation                 72.034317  162.787818
# family_practice                                      71.078930  111.338914
# general_practice                                     67.897368  111.378720
# osteopathic_manipulative_medicine                    63.683580   98.714181
# neurology                                            61.352941  112.256689
# geriatric_medicine                                   72.878981   96.500000
# hematology_oncology                                  66.564967   88.675893
# medical_oncology                                     58.620000   76.142857
# internal_medicine                                    56.523776   97.404292
# pediatric_medicine                                   42.795918   97.158259
# sports_medicine                                      12.090909   21.263889
# nephrology                                           43.672772   71.113333
# nurse_practitioner                                   14.030303   56.132143
# specialist                                            6.306324   37.857456
# infectious_disease                                    0.000000   40.281853
# radiation_oncology                                   26.833333   37.171659
# neurosurgery                                         23.217391   34.441622
# orthopaedic_surgery                                  14.058824   24.927083
# physician_assistant                                  10.095238   38.473684
# diagnostic_radiology                                  0.000000   18.428571
# critical_care_(intensivists)                          5.705882   45.596591
# orthopedic_surgery                                   17.840000   25.543531
# pulmonary_disease                                     0.000000   36.830975
# registered_nurse                                     11.447173   40.928138
# certified_clinical_nurse_specialist                   0.000000    4.564103
# cardiology                                            0.000000   29.380471
# gynecological_oncology                               11.664322   22.468860
# podiatry                                             10.055556   18.372881
# gastroenterology                                      0.000000    8.824405
# surgical_oncology                                     7.500000   11.839161
# colorectal_surgery_(formerly_proctology)             10.536856   13.853659
# student_in_an_organized_health_care_education_t...    6.000000    9.774155
# cardiac_surgery                                       9.338983   12.112745
# vascular_surgery                                      8.290698   12.340909
# interventional_cardiology                             0.000000    0.000000
# allergy_immunology                                    0.000000    0.000000
#
#
#                                                            max
# specialty
# interventional_pain_management                      446.773723
# pain_management                                     516.011429
# anesthesiology                                      596.565217
# rheumatology                                        242.336364
# physical_medicine_and_rehabilitation                434.066667
# family_practice                                     417.352941
# general_practice                                    355.500000
# osteopathic_manipulative_medicine                   176.285012
# neurology                                           368.145455
# geriatric_medicine                                  243.096154
# hematology_oncology                                 214.800000
# medical_oncology                                    179.642857
# internal_medicine                                   471.861386
# pediatric_medicine                                  196.107143
# sports_medicine                                     336.126623
# nephrology                                          266.573171
# nurse_practitioner                                  413.729730
# specialist                                          251.139535
# infectious_disease                                  270.862069
# radiation_oncology                                   81.285714
# neurosurgery                                        180.315385
# orthopaedic_surgery                                 160.719512
# physician_assistant                                 324.627907
# diagnostic_radiology                                178.922680
# critical_care_(intensivists)                         93.105263
# orthopedic_surgery                                  270.183486
# pulmonary_disease                                   165.542373
# registered_nurse                                     68.375000
# certified_clinical_nurse_specialist                 191.349515
# cardiology                                          143.323232
# gynecological_oncology                               48.250000
# podiatry                                            127.161290
# gastroenterology                                    262.642857
# surgical_oncology                                    61.000000
# colorectal_surgery_(formerly_proctology)             40.575758
# student_in_an_organized_health_care_education_t...  136.659091
# cardiac_surgery                                      60.086957
# vascular_surgery                                     61.873418
# interventional_cardiology                           119.692308
# allergy_immunology                                  350.230769

# %% [markdown]
# ## Overdose deaths by states

# %%
num_pres = eda_df.groupby('state').size()
num_longer = eda_df['op_longer'].groupby(eda_df['state']).sum()
ratio_pres_longer = (num_longer / num_pres).sort_values(ascending=False)
tmp = pd.concat([num_pres, num_longer, ratio_pres_longer], axis = 1)
tmp.columns = ['num_prescriber', 'num_longer', 'ratio_of_longer']
tmp['state'] = tmp.index
tmp = tmp.sort_values(by='ratio_of_longer', ascending=False)

# %%
overdose = pd.read_csv("dataset/overdoses.csv", thousands = ",")
overdose = overdose.set_index('Abbrev')
overdose.Deaths = pd.to_numeric(overdose.Deaths)
overdose.Population = pd.to_numeric(overdose.Population)
overdose['death_per_cap'] = 100000 * overdose['Deaths'] / overdose['Population']

# %%
overdose = pd.concat([overdose, tmp], axis = 1)

# %%
overdose = overdose.sort_values(by='ratio_of_longer', ascending=False)
overdose
# Out:
#              State  Population  Deaths  death_per_cap  num_prescriber  \
# MT         Montana   1015165.0   125.0      12.313269              43
# WY         Wyoming    582658.0   109.0      18.707372              21
# AK          Alaska    735132.0   124.0      16.867719              28
# NM      New Mexico   2085287.0   547.0      26.231401             138
# UT            Utah   2900872.0   603.0      20.786853             132
# OK        Oklahoma   3850568.0   777.0      20.178841             186
# SC  South Carolina   4774839.0   701.0      14.681123             219
# OR          Oregon   3930065.0   522.0      13.282223             209
# IA            Iowa   3090416.0   264.0       8.542539             178
# MI        Michigan   9895622.0  1762.0      17.805854             714
# IN         Indiana   6570902.0  1172.0      17.836212             390
# NC  North Carolina   9848060.0  1358.0      13.789518             494
# ME           Maine   1328302.0   216.0      16.261362              77
# WA      Washington   6971406.0   979.0      14.043078             300
# AR        Arkansas   2959373.0   356.0      12.029575             155
# NV          Nevada   2790136.0   545.0      19.533098             148
# CO        Colorado   5268367.0   899.0      17.064111             236
# KY        Kentucky   4395295.0  1077.0      24.503475             289
# KS          Kansas   2893957.0   332.0      11.472182             160
# RI    Rhode Island   1051511.0   247.0      23.490006              69
# WV   West Virginia   1854304.0   627.0      33.813226             143
# DE        Delaware    925749.0   189.0      20.415901              62
# ID           Idaho   1612136.0   212.0      13.150255              82
# AL         Alabama   4833722.0   723.0      14.957418             235
# CT     Connecticut   3596080.0   623.0      17.324420             216
# NJ      New Jersey   8899339.0  1253.0      14.079697             483
# NE        Nebraska   1868516.0   125.0       6.689801              85
# AZ         Arizona   6626624.0  1211.0      18.274766             401
# MN       Minnesota   5420380.0   517.0       9.538077             313
# MO        Missouri   6044171.0  1067.0      17.653372             331
# IL        Illinois  12882135.0  1705.0      13.235384             760
# TN       Tennessee   6495978.0  1269.0      19.535165             397
# ND    North Dakota    723393.0    43.0       5.944210              55
# WI       Wisconsin   5742713.0   853.0      14.853607             343
# VA        Virginia   8260405.0   980.0      11.863825             418
# CA      California  38332521.0  4521.0      11.794163            1916
# MD        Maryland   5928814.0  1070.0      18.047454             358
# NH   New Hampshire   1323459.0   334.0      25.236898              64
# MA   Massachusetts   6692824.0  1289.0      19.259434             433
# PA    Pennsylvania  12773801.0  2732.0      21.387526             744
# OH            Ohio  11570808.0  2744.0      23.714852             725
# LA       Louisiana   4625470.0   777.0      16.798293             258
# TX           Texas  26448193.0  2601.0       9.834320            1277
# FL         Florida  19552860.0  2634.0      13.471175            1325
# GA         Georgia   9992167.0  1206.0      12.069454             491
# NY        New York  19651127.0  2300.0      11.704163            1280
# HI          Hawaii   1404054.0   157.0      11.181906              66
# MS     Mississippi   2991207.0   336.0      11.232924             141
# VT         Vermont    626630.0    83.0      13.245456              27
# DC             NaN         NaN     NaN            NaN              45
# SD    South Dakota    844877.0    63.0       7.456707              43
#
#     num_longer  ratio_of_longer state
# MT        19.0         0.441860    MT
# WY         8.0         0.380952    WY
# AK         9.0         0.321429    AK
# NM        42.0         0.304348    NM
# UT        36.0         0.272727    UT
# OK        47.0         0.252688    OK
# SC        55.0         0.251142    SC
# OR        52.0         0.248804    OR
# IA        44.0         0.247191    IA
# MI       175.0         0.245098    MI
# IN        95.0         0.243590    IN
# NC       116.0         0.234818    NC
# ME        18.0         0.233766    ME
# WA        70.0         0.233333    WA
# AR        36.0         0.232258    AR
# NV        34.0         0.229730    NV
# CO        54.0         0.228814    CO
# KY        65.0         0.224913    KY
# KS        35.0         0.218750    KS
# RI        15.0         0.217391    RI
# WV        31.0         0.216783    WV
# DE        13.0         0.209677    DE
# ID        17.0         0.207317    ID
# AL        48.0         0.204255    AL
# CT        44.0         0.203704    CT
# NJ        97.0         0.200828    NJ
# NE        16.0         0.188235    NE
# AZ        75.0         0.187032    AZ
# MN        58.0         0.185304    MN
# MO        61.0         0.184290    MO
# IL       140.0         0.184211    IL
# TN        73.0         0.183879    TN
# ND        10.0         0.181818    ND
# WI        61.0         0.177843    WI
# VA        74.0         0.177033    VA
# CA       339.0         0.176931    CA
# MD        63.0         0.175978    MD
# NH        11.0         0.171875    NH
# MA        74.0         0.170901    MA
# PA       126.0         0.169355    PA
# OH       121.0         0.166897    OH
# LA        43.0         0.166667    LA
# TX       190.0         0.148786    TX
# FL       196.0         0.147925    FL
# GA        72.0         0.146640    GA
# NY       187.0         0.146094    NY
# HI         9.0         0.136364    HI
# MS        19.0         0.134752    MS
# VT         3.0         0.111111    VT
# DC         5.0         0.111111    DC
# SD         2.0         0.046512    SD

# %%
overdose['ratio_of_longer'].mean()
# Out:
# 0.20556290548941655

# %%
plt.figure(figsize=(9, 6))
s = .1 * overdose['Deaths'] 
plt.scatter(y=overdose['death_per_cap'], x=overdose['ratio_of_longer'], 
           s = s , 
            c = 'r')
plt.text(0.04, 6, 'SD')
plt.text(.44, 11, 'MT')
plt.text(.22, 33, 'WV')
plt.text(0.30, 25, 'NM')
plt.text(0.38, 18, 'WY')
plt.text(0.31, 16, 'AK')
plt.xlabel('Average ratio healthcare provider who prescribed longer than 84 days in 2015')
plt.ylabel('Opiates related overdose deaths per 100,000 in 2014')
#plt.savefig('assets/overdose_vs_ratio.png')
plt.show()

# %% [markdown]
# # Specialty vs opioids

# %%
cols_to_keep = ['specialty', 'op_longer'] + op_names
small = eda_df.loc[:, cols_to_keep]
small = small.loc[:, (small != 0).any(axis=0)]
small.shape
# Out:
# (17703, 20)

# %%
#freq_specialty = list(small.specialty.value_counts(ascending=False).index[:25])
small = small.loc[small['specialty'].isin(top40), :]
grouped = small.groupby('specialty').corrwith(small['op_longer'])
grouped = grouped.dropna(how='all', axis=1)
grouped = grouped.drop('op_longer', 1)

# %%
#grouped

# %%
grouped.mean(axis=0).sort_values(ascending=False)
# Out:
# hydrocodone_acetaminophen         0.530958
# oxycodone_hcl_acetaminophen       0.393568
# buprenorphine_hcl                 0.384482
# tramadol_hcl                      0.371607
# morphine_sulfate                  0.329085
# oxycodone_hcl                     0.319347
# fentanyl                          0.270552
# methadone_hcl                     0.231952
# oxymorphone_hcl                   0.199150
# acetaminophen_with_codeine        0.197754
# hydromorphone_hcl                 0.187464
# tapentadol_hcl                    0.088624
# butorphanol_tartrate              0.084832
# morphine_sulfate_naltrexone       0.082632
# buprenorphine                     0.082266
# hydrocodone_ibuprofen             0.061714
# dhcodeine_bt_acetaminophn_caff    0.047339
# tramadol_hcl_acetaminophen        0.026578
# dtype: float64

# %%
grouped.mean(axis=1).sort_values(ascending=False)
# Out:
# specialty
# certified_clinical_nurse_specialist                               0.644964
# diagnostic_radiology                                              0.621501
# allergy_immunology                                                0.616912
# sports_medicine                                                   0.562651
# pediatric_medicine                                                0.532361
# infectious_disease                                                0.419102
# pulmonary_disease                                                 0.408360
# neurosurgery                                                      0.380642
# orthopaedic_surgery                                               0.378103
# gastroenterology                                                  0.325862
# anesthesiology                                                    0.299354
# physical_medicine_and_rehabilitation                              0.298245
# osteopathic_manipulative_medicine                                 0.297619
# interventional_pain_management                                    0.288527
# specialist                                                        0.278988
# physician_assistant                                               0.278071
# cardiology                                                        0.274880
# geriatric_medicine                                                0.267945
# pain_management                                                   0.262329
# orthopedic_surgery                                                0.253016
# nurse_practitioner                                                0.249547
# internal_medicine                                                 0.229341
# nephrology                                                        0.229087
# general_practice                                                  0.207721
# family_practice                                                   0.202898
# neurology                                                         0.192109
# medical_oncology                                                  0.184922
# rheumatology                                                      0.170293
# hematology_oncology                                               0.120627
# podiatry                                                          0.115616
# student_in_an_organized_health_care_education_training_program    0.110392
# critical_care_(intensivists)                                      0.063728
# interventional_cardiology                                        -0.049344
# cardiac_surgery                                                        NaN
# colorectal_surgery_(formerly_proctology)                               NaN
# gynecological_oncology                                                 NaN
# radiation_oncology                                                     NaN
# registered_nurse                                                       NaN
# surgical_oncology                                                      NaN
# vascular_surgery                                                       NaN
# dtype: float64

# %%
plt.figure(figsize=(7, 7))
sorted_op = grouped.mean(axis=0).sort_values(ascending=False).index
sorted_spec = grouped.mean(axis=1).sort_values(ascending=False).index[:20]
grouped = grouped.loc[sorted_spec, :]
grouped = grouped.loc[:, sorted_op]

cmap = sns.diverging_palette(220, 10, as_cmap=True)
g = sns.heatmap(grouped.fillna(0), square=True, cmap=cmap)
#plt.savefig('assets/clustermap_specialty_vs_op.png', orientation='landscape', dpi=199)
plt.title('Heatmap of correlation to the label: op_longer')
plt.ylabel('specialty')
plt.xlabel('opioids')
plt.show()

# %% [markdown]
# # Non-opioid vs Op_longer
#
# #### Antibiotics

# %%
drug_name_dict.keys()
# Out:
# dict_keys(['High Risk Medication (HRM) Drug Flag', 'Antipsychotic Drug Flag', 'Antibiotic Drug Flag', 'others', 'Opioid Drug Flag'])

# %%
antibiotic_names = drug_name_dict['Antibiotic Drug Flag'] + ['op_longer', 'specialty']
antibiotic = eda_df.loc[:, antibiotic_names]
antibiotic = antibiotic.loc[antibiotic['specialty'].isin(top20), :]
antibiotic_corr = antibiotic.groupby('specialty').corrwith(antibiotic['op_longer'])
antibiotic_corr = antibiotic_corr.dropna(how='all', axis=1)
antibiotic_corr = antibiotic_corr.drop('op_longer', 1)

# %%
antibiotic_corr
# Out:
#                                       amoxicillin  amoxicillin_potassium_clav  \
# specialty
# anesthesiology                           0.077022                         NaN
# family_practice                          0.179374                    0.093466
# general_practice                         0.252581                    0.136671
# geriatric_medicine                       0.078052                    0.016893
# hematology_oncology                     -0.051934                   -0.015913
# infectious_disease                       0.096568                   -0.134809
# internal_medicine                        0.303450                    0.250883
# interventional_pain_management                NaN                         NaN
# medical_oncology                        -0.050373                    0.177844
# nephrology                               0.131926                    0.363768
# neurology                                0.038792                    0.115390
# nurse_practitioner                       0.054216                    0.080562
# osteopathic_manipulative_medicine       -0.081980                    0.341978
# pain_management                               NaN                         NaN
# pediatric_medicine                       0.249956                    0.183928
# physical_medicine_and_rehabilitation     0.127997                    0.082632
# radiation_oncology                            NaN                         NaN
# rheumatology                             0.076597                   -0.029326
# specialist                              -0.118961                   -0.085749
# sports_medicine                               NaN                   -0.123091
#
#                                       ampicillin_trihydrate  azithromycin  \
# specialty
# anesthesiology                                          NaN           NaN
# family_practice                                    0.036787      0.170698
# general_practice                                   0.104010      0.212099
# geriatric_medicine                                      NaN      0.148640
# hematology_oncology                                     NaN      0.037858
# infectious_disease                                      NaN     -0.092267
# internal_medicine                                  0.079154      0.345184
# interventional_pain_management                          NaN           NaN
# medical_oncology                                        NaN      0.414238
# nephrology                                         0.157235      0.304406
# neurology                                               NaN      0.154045
# nurse_practitioner                                 0.049955      0.081932
# osteopathic_manipulative_medicine                       NaN      0.232970
# pain_management                                         NaN           NaN
# pediatric_medicine                                      NaN      0.444320
# physical_medicine_and_rehabilitation                    NaN      0.082632
# radiation_oncology                                      NaN           NaN
# rheumatology                                            NaN      0.190159
# specialist                                              NaN     -0.122157
# sports_medicine                                         NaN      0.425164
#
#                                       cefaclor  cefadroxil  cefazolin_sodium  \
# specialty
# anesthesiology                             NaN         NaN               NaN
# family_practice                       0.023812    0.010717               NaN
# general_practice                     -0.062839   -0.062839               NaN
# geriatric_medicine                         NaN         NaN               NaN
# hematology_oncology                        NaN         NaN               NaN
# infectious_disease                         NaN   -0.057639         -0.057639
# internal_medicine                          NaN    0.045545               NaN
# interventional_pain_management             NaN         NaN               NaN
# medical_oncology                           NaN         NaN               NaN
# nephrology                                 NaN         NaN               NaN
# neurology                                  NaN    0.084832               NaN
# nurse_practitioner                   -0.009810    0.016319               NaN
# osteopathic_manipulative_medicine          NaN         NaN               NaN
# pain_management                            NaN         NaN               NaN
# pediatric_medicine                         NaN         NaN               NaN
# physical_medicine_and_rehabilitation       NaN         NaN               NaN
# radiation_oncology                         NaN         NaN               NaN
# rheumatology                               NaN         NaN               NaN
# specialist                                 NaN         NaN               NaN
# sports_medicine                            NaN         NaN               NaN
#
#                                       cefdinir  cefepime_hcl  \
# specialty
# anesthesiology                             NaN           NaN
# family_practice                       0.067791      0.023812
# general_practice                      0.077984           NaN
# geriatric_medicine                   -0.087117           NaN
# hematology_oncology                        NaN           NaN
# infectious_disease                    0.354068     -0.057639
# internal_medicine                     0.067914     -0.011945
# interventional_pain_management             NaN           NaN
# medical_oncology                           NaN           NaN
# nephrology                           -0.030724           NaN
# neurology                             0.120228           NaN
# nurse_practitioner                   -0.013094           NaN
# osteopathic_manipulative_medicine          NaN           NaN
# pain_management                            NaN           NaN
# pediatric_medicine                    0.272019           NaN
# physical_medicine_and_rehabilitation       NaN           NaN
# radiation_oncology                         NaN           NaN
# rheumatology                               NaN           NaN
# specialist                                 NaN           NaN
# sports_medicine                            NaN           NaN
#
#                                       cefpodoxime_proxetil  cefprozil  \
# specialty
# anesthesiology                                         NaN        NaN
# family_practice                                   0.028481   0.024826
# general_practice                                       NaN   0.002104
# geriatric_medicine                                     NaN        NaN
# hematology_oncology                                    NaN   0.098517
# infectious_disease                               -0.057639        NaN
# internal_medicine                                -0.034875   0.040655
# interventional_pain_management                         NaN        NaN
# medical_oncology                                       NaN        NaN
# nephrology                                        0.157235        NaN
# neurology                                              NaN        NaN
# nurse_practitioner                               -0.009810        NaN
# osteopathic_manipulative_medicine                      NaN        NaN
# pain_management                                        NaN        NaN
# pediatric_medicine                                     NaN   0.264575
# physical_medicine_and_rehabilitation                   NaN        NaN
# radiation_oncology                                     NaN        NaN
# rheumatology                                           NaN        NaN
# specialist                                             NaN        NaN
# sports_medicine                                        NaN        NaN
#
#                                       ceftriaxone_na_dextrose_iso  \
# specialty
# anesthesiology                                                NaN
# family_practice                                          0.023812
# general_practice                                              NaN
# geriatric_medicine                                            NaN
# hematology_oncology                                           NaN
# infectious_disease                                            NaN
# internal_medicine                                             NaN
# interventional_pain_management                                NaN
# medical_oncology                                              NaN
# nephrology                                                    NaN
# neurology                                                     NaN
# nurse_practitioner                                            NaN
# osteopathic_manipulative_medicine                             NaN
# pain_management                                               NaN
# pediatric_medicine                                            NaN
# physical_medicine_and_rehabilitation                          NaN
# radiation_oncology                                            NaN
# rheumatology                                                  NaN
# specialist                                                    NaN
# sports_medicine                                               NaN
#
#                                       ceftriaxone_sodium  cefuroxime_axetil  \
# specialty
# anesthesiology                                       NaN                NaN
# family_practice                                 0.061783           0.114432
# general_practice                                0.178123           0.094450
# geriatric_medicine                              0.160436          -0.079082
# hematology_oncology                                  NaN           0.042525
# infectious_disease                             -0.080031          -0.057639
# internal_medicine                               0.059255           0.135487
# interventional_pain_management                       NaN                NaN
# medical_oncology                                     NaN                NaN
# nephrology                                           NaN           0.268438
# neurology                                            NaN                NaN
# nurse_practitioner                              0.026684           0.019801
# osteopathic_manipulative_medicine                    NaN                NaN
# pain_management                                      NaN                NaN
# pediatric_medicine                                   NaN          -0.125988
# physical_medicine_and_rehabilitation                 NaN                NaN
# radiation_oncology                                   NaN                NaN
# rheumatology                                         NaN          -0.129947
# specialist                                           NaN                NaN
# sports_medicine                                      NaN                NaN
#
#                                       cephalexin  ciprofloxacin_hcl  \
# specialty
# anesthesiology                          0.172168           0.077022
# family_practice                         0.144240           0.219593
# general_practice                        0.160952           0.264632
# geriatric_medicine                      0.125120           0.281612
# hematology_oncology                     0.032201          -0.018580
# infectious_disease                     -0.177360          -0.081851
# internal_medicine                       0.269021           0.339889
# interventional_pain_management         -0.177535                NaN
# medical_oncology                        0.050362          -0.070772
# nephrology                              0.073278           0.124728
# neurology                               0.021949           0.117849
# nurse_practitioner                      0.052509           0.115862
# osteopathic_manipulative_medicine       0.339367           0.495024
# pain_management                         0.074099                NaN
# pediatric_medicine                      0.314105           0.527691
# physical_medicine_and_rehabilitation    0.082632           0.162320
# radiation_oncology                           NaN                NaN
# rheumatology                            0.005779           0.001830
# specialist                             -0.123369          -0.124993
# sports_medicine                         0.677003           0.541698
#
#                                       ciprofloxacin_lactate_d5w  \
# specialty
# anesthesiology                                              NaN
# family_practice                                        0.023812
# general_practice                                            NaN
# geriatric_medicine                                          NaN
# hematology_oncology                                         NaN
# infectious_disease                                          NaN
# internal_medicine                                           NaN
# interventional_pain_management                              NaN
# medical_oncology                                            NaN
# nephrology                                                  NaN
# neurology                                                   NaN
# nurse_practitioner                                          NaN
# osteopathic_manipulative_medicine                           NaN
# pain_management                                             NaN
# pediatric_medicine                                          NaN
# physical_medicine_and_rehabilitation                        NaN
# radiation_oncology                                          NaN
# rheumatology                                                NaN
# specialist                                                  NaN
# sports_medicine                                             NaN
#
#                                       clarithromycin  clindamycin_hcl  \
# specialty
# anesthesiology                                   NaN              NaN
# family_practice                             0.047319         0.032786
# general_practice                            0.095904        -0.039712
# geriatric_medicine                               NaN        -0.087117
# hematology_oncology                              NaN              NaN
# infectious_disease                         -0.057639        -0.068600
# internal_medicine                           0.065628         0.125622
# interventional_pain_management                   NaN              NaN
# medical_oncology                                 NaN              NaN
# nephrology                                       NaN         0.157235
# neurology                                        NaN         0.084832
# nurse_practitioner                         -0.009835         0.027289
# osteopathic_manipulative_medicine                NaN              NaN
# pain_management                                  NaN              NaN
# pediatric_medicine                               NaN        -0.181093
# physical_medicine_and_rehabilitation             NaN              NaN
# radiation_oncology                               NaN              NaN
# rheumatology                                0.054578              NaN
# specialist                                       NaN              NaN
# sports_medicine                                  NaN              NaN
#
#                                       clindamycin_phosphate  \
# specialty
# anesthesiology                                          NaN
# family_practice                                    0.023812
# general_practice                                        NaN
# geriatric_medicine                                      NaN
# hematology_oncology                                     NaN
# infectious_disease                                      NaN
# internal_medicine                                  0.030025
# interventional_pain_management                          NaN
# medical_oncology                                  -0.050373
# nephrology                                              NaN
# neurology                                               NaN
# nurse_practitioner                                -0.021595
# osteopathic_manipulative_medicine                       NaN
# pain_management                                         NaN
# pediatric_medicine                                      NaN
# physical_medicine_and_rehabilitation                    NaN
# radiation_oncology                                      NaN
# rheumatology                                            NaN
# specialist                                              NaN
# sports_medicine                                         NaN
#
#                                       dicloxacillin_sodium  \
# specialty
# anesthesiology                                         NaN
# family_practice                                   0.023812
# general_practice                                       NaN
# geriatric_medicine                                     NaN
# hematology_oncology                                    NaN
# infectious_disease                                     NaN
# internal_medicine                                -0.011945
# interventional_pain_management                         NaN
# medical_oncology                                       NaN
# nephrology                                             NaN
# neurology                                              NaN
# nurse_practitioner                               -0.013868
# osteopathic_manipulative_medicine                      NaN
# pain_management                                        NaN
# pediatric_medicine                                     NaN
# physical_medicine_and_rehabilitation                   NaN
# radiation_oncology                                     NaN
# rheumatology                                           NaN
# specialist                                             NaN
# sports_medicine                                        NaN
#
#                                       doxycycline_hyclate  \
# specialty
# anesthesiology                                        NaN
# family_practice                                  0.119218
# general_practice                                 0.129782
# geriatric_medicine                               0.217545
# hematology_oncology                                   NaN
# infectious_disease                              -0.220256
# internal_medicine                                0.160307
# interventional_pain_management                        NaN
# medical_oncology                                -0.050373
# nephrology                                       0.110814
# neurology                                             NaN
# nurse_practitioner                               0.000822
# osteopathic_manipulative_medicine               -0.206725
# pain_management                                       NaN
# pediatric_medicine                               0.096724
# physical_medicine_and_rehabilitation             0.082632
# radiation_oncology                                    NaN
# rheumatology                                     0.054578
# specialist                                            NaN
# sports_medicine                                       NaN
#
#                                       doxycycline_monohydrate  \
# specialty
# anesthesiology                                            NaN
# family_practice                                      0.024977
# general_practice                                    -0.039333
# geriatric_medicine                                   0.204980
# hematology_oncology                                       NaN
# infectious_disease                                   0.226444
# internal_medicine                                    0.053326
# interventional_pain_management                            NaN
# medical_oncology                                          NaN
# nephrology                                                NaN
# neurology                                                 NaN
# nurse_practitioner                                   0.008384
# osteopathic_manipulative_medicine                         NaN
# pain_management                                           NaN
# pediatric_medicine                                   0.264575
# physical_medicine_and_rehabilitation                      NaN
# radiation_oncology                                        NaN
# rheumatology                                              NaN
# specialist                                                NaN
# sports_medicine                                           NaN
#
#                                       ertapenem_sodium  erythromycin_base  \
# specialty
# anesthesiology                                     NaN                NaN
# family_practice                               0.023812           0.022787
# general_practice                                   NaN                NaN
# geriatric_medicine                           -0.087117          -0.087117
# hematology_oncology                                NaN                NaN
# infectious_disease                           -0.097698                NaN
# internal_medicine                             0.010380          -0.020302
# interventional_pain_management                     NaN                NaN
# medical_oncology                                   NaN                NaN
# nephrology                                         NaN                NaN
# neurology                                          NaN                NaN
# nurse_practitioner                                 NaN                NaN
# osteopathic_manipulative_medicine                  NaN                NaN
# pain_management                                    NaN                NaN
# pediatric_medicine                                 NaN                NaN
# physical_medicine_and_rehabilitation               NaN                NaN
# radiation_oncology                                 NaN                NaN
# rheumatology                                       NaN                NaN
# specialist                                         NaN                NaN
# sports_medicine                                    NaN                NaN
#
#                                       erythromycin_ethylsuccinate  \
# specialty
# anesthesiology                                                NaN
# family_practice                                         -0.016859
# general_practice                                              NaN
# geriatric_medicine                                            NaN
# hematology_oncology                                           NaN
# infectious_disease                                            NaN
# internal_medicine                                             NaN
# interventional_pain_management                                NaN
# medical_oncology                                              NaN
# nephrology                                                    NaN
# neurology                                                     NaN
# nurse_practitioner                                            NaN
# osteopathic_manipulative_medicine                             NaN
# pain_management                                               NaN
# pediatric_medicine                                            NaN
# physical_medicine_and_rehabilitation                          NaN
# radiation_oncology                                            NaN
# rheumatology                                                  NaN
# specialist                                                    NaN
# sports_medicine                                               NaN
#
#                                       fosfomycin_tromethamine  \
# specialty
# anesthesiology                                            NaN
# family_practice                                     -0.016859
# general_practice                                          NaN
# geriatric_medicine                                        NaN
# hematology_oncology                                       NaN
# infectious_disease                                        NaN
# internal_medicine                                   -0.010103
# interventional_pain_management                            NaN
# medical_oncology                                          NaN
# nephrology                                                NaN
# neurology                                                 NaN
# nurse_practitioner                                        NaN
# osteopathic_manipulative_medicine                         NaN
# pain_management                                           NaN
# pediatric_medicine                                        NaN
# physical_medicine_and_rehabilitation                      NaN
# radiation_oncology                                        NaN
# rheumatology                                              NaN
# specialist                                                NaN
# sports_medicine                                           NaN
#
#                                       gentamicin_sulfate  levofloxacin  \
# specialty
# anesthesiology                                       NaN           NaN
# family_practice                                 0.044323      0.160741
# general_practice                               -0.038059      0.183776
# geriatric_medicine                              0.204980      0.224948
# hematology_oncology                                  NaN     -0.042321
# infectious_disease                             -0.057639     -0.169243
# internal_medicine                               0.061787      0.182820
# interventional_pain_management                       NaN           NaN
# medical_oncology                                     NaN     -0.026606
# nephrology                                     -0.042519      0.263531
# neurology                                            NaN      0.119741
# nurse_practitioner                              0.016845      0.076910
# osteopathic_manipulative_medicine                    NaN      0.576081
# pain_management                                      NaN     -0.217667
# pediatric_medicine                                   NaN      0.326778
# physical_medicine_and_rehabilitation            0.082632      0.003597
# radiation_oncology                                   NaN           NaN
# rheumatology                                         NaN      0.010915
# specialist                                           NaN     -0.085749
# sports_medicine                                      NaN           NaN
#
#                                       levofloxacin_d5w  meropenem  \
# specialty
# anesthesiology                                     NaN        NaN
# family_practice                               0.023812        NaN
# general_practice                                   NaN        NaN
# geriatric_medicine                                 NaN        NaN
# hematology_oncology                                NaN        NaN
# infectious_disease                                 NaN  -0.057639
# internal_medicine                            -0.011945  -0.011945
# interventional_pain_management                     NaN        NaN
# medical_oncology                                   NaN        NaN
# nephrology                                         NaN        NaN
# neurology                                          NaN        NaN
# nurse_practitioner                                 NaN        NaN
# osteopathic_manipulative_medicine                  NaN        NaN
# pain_management                                    NaN        NaN
# pediatric_medicine                                 NaN        NaN
# physical_medicine_and_rehabilitation               NaN        NaN
# radiation_oncology                                 NaN        NaN
# rheumatology                                       NaN        NaN
# specialist                                         NaN        NaN
# sports_medicine                                    NaN        NaN
#
#                                       metronidazole  minocycline_hcl  \
# specialty
# anesthesiology                                  NaN              NaN
# family_practice                            0.106029         0.027564
# general_practice                           0.069705        -0.086646
# geriatric_medicine                         0.133672              NaN
# hematology_oncology                        0.098517              NaN
# infectious_disease                         0.171239        -0.057639
# internal_medicine                          0.174121         0.017404
# interventional_pain_management                  NaN              NaN
# medical_oncology                                NaN         0.206793
# nephrology                                 0.185905              NaN
# neurology                                  0.084832              NaN
# nurse_practitioner                        -0.001712        -0.018460
# osteopathic_manipulative_medicine          0.372104              NaN
# pain_management                                 NaN              NaN
# pediatric_medicine                         0.193293              NaN
# physical_medicine_and_rehabilitation            NaN              NaN
# radiation_oncology                              NaN              NaN
# rheumatology                              -0.129947         0.091787
# specialist                                -0.124964              NaN
# sports_medicine                                 NaN              NaN
#
#                                       moxifloxacin_hcl  neomycin_sulfate  \
# specialty
# anesthesiology                                     NaN               NaN
# family_practice                               0.002990               NaN
# general_practice                             -0.062839               NaN
# geriatric_medicine                           -0.032623               NaN
# hematology_oncology                          -0.041095               NaN
# infectious_disease                                 NaN               NaN
# internal_medicine                             0.012306               NaN
# interventional_pain_management                     NaN               NaN
# medical_oncology                                   NaN               NaN
# nephrology                                         NaN               NaN
# neurology                                          NaN               NaN
# nurse_practitioner                                 NaN         -0.013751
# osteopathic_manipulative_medicine                  NaN               NaN
# pain_management                                    NaN               NaN
# pediatric_medicine                                 NaN               NaN
# physical_medicine_and_rehabilitation               NaN               NaN
# radiation_oncology                                 NaN               NaN
# rheumatology                                       NaN               NaN
# specialist                                         NaN               NaN
# sports_medicine                                    NaN               NaN
#
#                                       nitrofurantoin_macrocrystal  \
# specialty
# anesthesiology                                                NaN
# family_practice                                          0.047153
# general_practice                                              NaN
# geriatric_medicine                                      -0.087117
# hematology_oncology                                           NaN
# infectious_disease                                            NaN
# internal_medicine                                        0.034824
# interventional_pain_management                                NaN
# medical_oncology                                              NaN
# nephrology                                              -0.030724
# neurology                                                     NaN
# nurse_practitioner                                       0.025596
# osteopathic_manipulative_medicine                             NaN
# pain_management                                               NaN
# pediatric_medicine                                            NaN
# physical_medicine_and_rehabilitation                          NaN
# radiation_oncology                                            NaN
# rheumatology                                                  NaN
# specialist                                                    NaN
# sports_medicine                                               NaN
#
#                                       nitrofurantoin_monohyd_m_cryst  \
# specialty
# anesthesiology                                                   NaN
# family_practice                                             0.106898
# general_practice                                            0.181409
# geriatric_medicine                                         -0.021269
# hematology_oncology                                         0.098517
# infectious_disease                                               NaN
# internal_medicine                                           0.188553
# interventional_pain_management                                   NaN
# medical_oncology                                                 NaN
# nephrology                                                  0.051424
# neurology                                                        NaN
# nurse_practitioner                                          0.083195
# osteopathic_manipulative_medicine                                NaN
# pain_management                                                  NaN
# pediatric_medicine                                         -0.125988
# physical_medicine_and_rehabilitation                             NaN
# radiation_oncology                                               NaN
# rheumatology                                                0.054578
# specialist                                                       NaN
# sports_medicine                                                  NaN
#
#                                       ofloxacin  penicillin_g_benzathine  \
# specialty
# anesthesiology                              NaN                      NaN
# family_practice                       -0.005323                      NaN
# general_practice                      -0.062839                  0.10401
# geriatric_medicine                          NaN                      NaN
# hematology_oncology                         NaN                      NaN
# infectious_disease                          NaN                      NaN
# internal_medicine                      0.018934                      NaN
# interventional_pain_management              NaN                      NaN
# medical_oncology                            NaN                      NaN
# nephrology                                  NaN                      NaN
# neurology                                   NaN                      NaN
# nurse_practitioner                     0.046800                      NaN
# osteopathic_manipulative_medicine           NaN                      NaN
# pain_management                             NaN                      NaN
# pediatric_medicine                    -0.125988                      NaN
# physical_medicine_and_rehabilitation        NaN                      NaN
# radiation_oncology                          NaN                      NaN
# rheumatology                                NaN                      NaN
# specialist                                  NaN                      NaN
# sports_medicine                             NaN                      NaN
#
#                                       penicillin_v_potassium  \
# specialty
# anesthesiology                                           NaN
# family_practice                                    -0.016346
# general_practice                                         NaN
# geriatric_medicine                                       NaN
# hematology_oncology                                      NaN
# infectious_disease                                       NaN
# internal_medicine                                   0.069013
# interventional_pain_management                           NaN
# medical_oncology                                         NaN
# nephrology                                               NaN
# neurology                                                NaN
# nurse_practitioner                                 -0.019446
# osteopathic_manipulative_medicine                        NaN
# pain_management                                          NaN
# pediatric_medicine                                       NaN
# physical_medicine_and_rehabilitation                     NaN
# radiation_oncology                                       NaN
# rheumatology                                             NaN
# specialist                                         -0.085749
# sports_medicine                                          NaN
#
#                                       piperacillin_tazo_dextrose_iso  \
# specialty
# anesthesiology                                                   NaN
# family_practice                                             0.023812
# general_practice                                                 NaN
# geriatric_medicine                                               NaN
# hematology_oncology                                              NaN
# infectious_disease                                               NaN
# internal_medicine                                                NaN
# interventional_pain_management                                   NaN
# medical_oncology                                                 NaN
# nephrology                                                       NaN
# neurology                                                        NaN
# nurse_practitioner                                               NaN
# osteopathic_manipulative_medicine                                NaN
# pain_management                                                  NaN
# pediatric_medicine                                               NaN
# physical_medicine_and_rehabilitation                             NaN
# radiation_oncology                                               NaN
# rheumatology                                                     NaN
# specialist                                                       NaN
# sports_medicine                                                  NaN
#
#                                       rifaximin  \
# specialty
# anesthesiology                              NaN
# family_practice                             NaN
# general_practice                            NaN
# geriatric_medicine                          NaN
# hematology_oncology                         NaN
# infectious_disease                          NaN
# internal_medicine                     -0.020208
# interventional_pain_management              NaN
# medical_oncology                            NaN
# nephrology                                  NaN
# neurology                                   NaN
# nurse_practitioner                          NaN
# osteopathic_manipulative_medicine           NaN
# pain_management                             NaN
# pediatric_medicine                          NaN
# physical_medicine_and_rehabilitation        NaN
# radiation_oncology                          NaN
# rheumatology                                NaN
# specialist                                  NaN
# sports_medicine                             NaN
#
#                                       sulfamethoxazole_trimethoprim  \
# specialty
# anesthesiology                                             0.077022
# family_practice                                            0.206266
# general_practice                                           0.290787
# geriatric_medicine                                         0.157467
# hematology_oncology                                       -0.013173
# infectious_disease                                         0.386503
# internal_medicine                                          0.275602
# interventional_pain_management                                  NaN
# medical_oncology                                           0.287744
# nephrology                                                 0.050610
# neurology                                                  0.084832
# nurse_practitioner                                         0.095486
# osteopathic_manipulative_medicine                          0.479751
# pain_management                                                 NaN
# pediatric_medicine                                         0.224441
# physical_medicine_and_rehabilitation                       0.140733
# radiation_oncology                                              NaN
# rheumatology                                               0.054578
# specialist                                                -0.121223
# sports_medicine                                            0.677003
#
#                                       trimethoprim  vancomycin_hcl
# specialty
# anesthesiology                                 NaN             NaN
# family_practice                           0.027883        0.046626
# general_practice                               NaN             NaN
# geriatric_medicine                             NaN       -0.029152
# hematology_oncology                            NaN             NaN
# infectious_disease                             NaN       -0.265100
# internal_medicine                              NaN       -0.019477
# interventional_pain_management                 NaN             NaN
# medical_oncology                               NaN             NaN
# nephrology                                     NaN             NaN
# neurology                                      NaN             NaN
# nurse_practitioner                             NaN             NaN
# osteopathic_manipulative_medicine              NaN             NaN
# pain_management                                NaN             NaN
# pediatric_medicine                             NaN       -0.125988
# physical_medicine_and_rehabilitation           NaN             NaN
# radiation_oncology                             NaN             NaN
# rheumatology                                   NaN             NaN
# specialist                                     NaN             NaN
# sports_medicine                                NaN             NaN

# %%
antibiotic_corr.mean(axis=0).sort_values(ascending=False)
# Out:
# ceftaroline_fosamil_acetate       0.189766
# tigecycline                       0.189766
# azithromycin                      0.184421
# cefdinir                          0.137364
# amoxicillin                       0.125428
# sulfamethoxazole_trimethoprim     0.124425
# cefuroxime_axetil                 0.100669
# amoxicillin_potassium_clav        0.099139
# ceftriaxone_sodium                0.098418
# metronidazole                     0.082626
# clindamycin_hcl                   0.082524
# vancomycin_hcl                    0.082094
# nitrofurantoin_monohyd_m_cryst    0.074261
# ciprofloxacin_hcl                 0.070394
# levofloxacin                      0.061886
# ampicillin_trihydrate             0.056736
# doxycycline_hyclate               0.051589
# ertapenem_sodium                  0.043841
# cephalexin                        0.043197
# nitrofurantoin_macrocrystal       0.032058
# clarithromycin                    0.027823
# cefixime                          0.027352
# ofloxacin                         0.021818
# trimethoprim                      0.021123
# amikacin_sulfate                  0.020006
# cefazolin_sodium                  0.019367
# linezolid                         0.019367
# doxycycline_monohydrate           0.015560
# erythromycin_base                 0.009959
# cefadroxil                        0.007421
# clindamycin_phosphate            -0.000254
# cefprozil                        -0.003701
# rifaximin                        -0.004072
# cefpodoxime_proxetil             -0.005640
# moxifloxacin_hcl                 -0.006003
# gentamicin_sulfate               -0.009186
# penicillin_v_potassium           -0.009418
# cefaclor                         -0.010312
# erythromycin_ethylsuccinate      -0.013301
# fosfomycin_tromethamine          -0.013301
# dicloxacillin_sodium             -0.014773
# meropenem                        -0.018698
# minocycline_hcl                  -0.038899
# cefepime_hcl                     -0.052876
# daptomycin                       -0.092450
# dtype: float64

# %% [markdown]
# #### Antipsychotic

# %%
antipsy_names = drug_name_dict['Antipsychotic Drug Flag'] + ['op_longer', 'specialty']
antipsy = eda_df.loc[:, antipsy_names]
antipsy = antipsy.loc[antipsy['specialty'].isin(top20), :]
antipsy_corr = antipsy.groupby('specialty').corrwith(antipsy['op_longer'])
antipsy_corr = antipsy_corr.dropna(how='all', axis=1)
antipsy_corr = antipsy_corr.drop('op_longer', 1)

# %%
antipsy_corr
# Out:
#                                       aripiprazole  asenapine_maleate  \
# specialty
# anesthesiology                                 NaN                NaN
# family_practice                           0.055995                NaN
# general_practice                          0.077899                NaN
# geriatric_medicine                       -0.087117                NaN
# hematology_oncology                            NaN                NaN
# infectious_disease                             NaN                NaN
# internal_medicine                         0.035944                NaN
# interventional_pain_management                 NaN                NaN
# medical_oncology                               NaN                NaN
# nephrology                                     NaN                NaN
# neurology                                      NaN                NaN
# nurse_practitioner                       -0.060070           -0.00981
# osteopathic_manipulative_medicine              NaN                NaN
# pain_management                           0.074099                NaN
# pediatric_medicine                             NaN                NaN
# physical_medicine_and_rehabilitation           NaN                NaN
# radiation_oncology                             NaN                NaN
# rheumatology                                   NaN                NaN
# specialist                                     NaN                NaN
# sports_medicine                                NaN                NaN
#
#                                       chlorpromazine_hcl  clozapine  \
# specialty
# anesthesiology                                       NaN        NaN
# family_practice                                      NaN        NaN
# general_practice                                0.104010        NaN
# geriatric_medicine                                   NaN        NaN
# hematology_oncology                                  NaN        NaN
# infectious_disease                                   NaN        NaN
# internal_medicine                              -0.016729  -0.003048
# interventional_pain_management                       NaN        NaN
# medical_oncology                                     NaN        NaN
# nephrology                                           NaN        NaN
# neurology                                            NaN        NaN
# nurse_practitioner                                   NaN  -0.023532
# osteopathic_manipulative_medicine                    NaN        NaN
# pain_management                                      NaN        NaN
# pediatric_medicine                                   NaN        NaN
# physical_medicine_and_rehabilitation                 NaN        NaN
# radiation_oncology                                   NaN        NaN
# rheumatology                                         NaN        NaN
# specialist                                           NaN        NaN
# sports_medicine                                      NaN        NaN
#
#                                       fluphenazine_hcl  haloperidol  \
# specialty
# anesthesiology                                     NaN          NaN
# family_practice                                    NaN     0.056505
# general_practice                                   NaN     0.147568
# geriatric_medicine                                 NaN          NaN
# hematology_oncology                                NaN    -0.041095
# infectious_disease                                 NaN          NaN
# internal_medicine                                  NaN     0.010896
# interventional_pain_management                     NaN          NaN
# medical_oncology                                   NaN          NaN
# nephrology                                         NaN          NaN
# neurology                                          NaN          NaN
# nurse_practitioner                           -0.019628    -0.014677
# osteopathic_manipulative_medicine                  NaN          NaN
# pain_management                                    NaN          NaN
# pediatric_medicine                                 NaN          NaN
# physical_medicine_and_rehabilitation               NaN          NaN
# radiation_oncology                                 NaN          NaN
# rheumatology                                       NaN          NaN
# specialist                                         NaN          NaN
# sports_medicine                                    NaN          NaN
#
#                                       haloperidol_decanoate  \
# specialty
# anesthesiology                                          NaN
# family_practice                                         NaN
# general_practice                                        NaN
# geriatric_medicine                                      NaN
# hematology_oncology                                     NaN
# infectious_disease                                      NaN
# internal_medicine                                 -0.011945
# interventional_pain_management                          NaN
# medical_oncology                                        NaN
# nephrology                                              NaN
# neurology                                               NaN
# nurse_practitioner                                      NaN
# osteopathic_manipulative_medicine                       NaN
# pain_management                                         NaN
# pediatric_medicine                                      NaN
# physical_medicine_and_rehabilitation                    NaN
# radiation_oncology                                      NaN
# rheumatology                                            NaN
# specialist                                              NaN
# sports_medicine                                         NaN
#
#                                       haloperidol_lactate  iloperidone  \
# specialty
# anesthesiology                                        NaN          NaN
# family_practice                                  0.023812     0.023812
# general_practice                                 0.104010          NaN
# geriatric_medicine                                    NaN          NaN
# hematology_oncology                                   NaN          NaN
# infectious_disease                                    NaN          NaN
# internal_medicine                               -0.017286          NaN
# interventional_pain_management                        NaN          NaN
# medical_oncology                                      NaN          NaN
# nephrology                                            NaN          NaN
# neurology                                             NaN          NaN
# nurse_practitioner                                    NaN    -0.009810
# osteopathic_manipulative_medicine                     NaN          NaN
# pain_management                                       NaN          NaN
# pediatric_medicine                                    NaN          NaN
# physical_medicine_and_rehabilitation                  NaN          NaN
# radiation_oncology                                    NaN          NaN
# rheumatology                                          NaN          NaN
# specialist                                            NaN          NaN
# sports_medicine                                       NaN          NaN
#
#                                       lurasidone_hcl  olanzapine  \
# specialty
# anesthesiology                                   NaN         NaN
# family_practice                             0.008281    0.058584
# general_practice                                 NaN    0.099008
# geriatric_medicine                               NaN    0.129780
# hematology_oncology                              NaN    0.098517
# infectious_disease                               NaN         NaN
# internal_medicine                           0.034448    0.063585
# interventional_pain_management                   NaN         NaN
# medical_oncology                                 NaN         NaN
# nephrology                                       NaN         NaN
# neurology                                        NaN    0.018538
# nurse_practitioner                         -0.038049   -0.023248
# osteopathic_manipulative_medicine                NaN         NaN
# pain_management                                  NaN         NaN
# pediatric_medicine                               NaN         NaN
# physical_medicine_and_rehabilitation             NaN         NaN
# radiation_oncology                               NaN         NaN
# rheumatology                                     NaN         NaN
# specialist                                       NaN         NaN
# sports_medicine                                  NaN         NaN
#
#                                       paliperidone  paliperidone_palmitate  \
# specialty
# anesthesiology                                 NaN                     NaN
# family_practice                                NaN                0.033677
# general_practice                               NaN                     NaN
# geriatric_medicine                             NaN                     NaN
# hematology_oncology                            NaN                     NaN
# infectious_disease                             NaN                     NaN
# internal_medicine                              NaN                0.024702
# interventional_pain_management                 NaN                     NaN
# medical_oncology                               NaN                     NaN
# nephrology                                     NaN                     NaN
# neurology                                      NaN                     NaN
# nurse_practitioner                        -0.01653               -0.039034
# osteopathic_manipulative_medicine              NaN                     NaN
# pain_management                                NaN                     NaN
# pediatric_medicine                             NaN                     NaN
# physical_medicine_and_rehabilitation           NaN                     NaN
# radiation_oncology                             NaN                     NaN
# rheumatology                                   NaN                     NaN
# specialist                                     NaN                     NaN
# sports_medicine                                NaN                     NaN
#
#                                       perphenazine  quetiapine_fumarate  \
# specialty
# anesthesiology                                 NaN                  NaN
# family_practice                           0.023812             0.146884
# general_practice                               NaN             0.083479
# geriatric_medicine                             NaN             0.155090
# hematology_oncology                            NaN            -0.041095
# infectious_disease                             NaN            -0.057639
# internal_medicine                              NaN             0.219833
# interventional_pain_management                 NaN                  NaN
# medical_oncology                               NaN                  NaN
# nephrology                                     NaN             0.222599
# neurology                                      NaN             0.148738
# nurse_practitioner                       -0.013567            -0.010729
# osteopathic_manipulative_medicine              NaN                  NaN
# pain_management                                NaN                  NaN
# pediatric_medicine                             NaN            -0.125988
# physical_medicine_and_rehabilitation           NaN             0.130309
# radiation_oncology                             NaN                  NaN
# rheumatology                                   NaN                  NaN
# specialist                                     NaN                  NaN
# sports_medicine                                NaN                  NaN
#
#                                       risperidone  risperidone_microspheres  \
# specialty
# anesthesiology                                NaN                       NaN
# family_practice                          0.092374                       NaN
# general_practice                         0.036769                       NaN
# geriatric_medicine                       0.199743                       NaN
# hematology_oncology                     -0.041095                       NaN
# infectious_disease                      -0.057639                       NaN
# internal_medicine                        0.111140                 -0.011945
# interventional_pain_management                NaN                       NaN
# medical_oncology                              NaN                       NaN
# nephrology                                    NaN                       NaN
# neurology                                0.074808                       NaN
# nurse_practitioner                       0.004636                 -0.013689
# osteopathic_manipulative_medicine             NaN                       NaN
# pain_management                               NaN                       NaN
# pediatric_medicine                            NaN                       NaN
# physical_medicine_and_rehabilitation          NaN                       NaN
# radiation_oncology                            NaN                       NaN
# rheumatology                                  NaN                       NaN
# specialist                                    NaN                       NaN
# sports_medicine                               NaN                       NaN
#
#                                       thioridazine_hcl  trifluoperazine_hcl  \
# specialty
# anesthesiology                                     NaN                  NaN
# family_practice                                    NaN                  NaN
# general_practice                                   NaN              0.10401
# geriatric_medicine                                 NaN                  NaN
# hematology_oncology                                NaN                  NaN
# infectious_disease                                 NaN                  NaN
# internal_medicine                                  NaN                  NaN
# interventional_pain_management                     NaN                  NaN
# medical_oncology                                   NaN                  NaN
# nephrology                                         NaN                  NaN
# neurology                                          NaN                  NaN
# nurse_practitioner                            -0.00981                  NaN
# osteopathic_manipulative_medicine                  NaN                  NaN
# pain_management                                    NaN                  NaN
# pediatric_medicine                                 NaN                  NaN
# physical_medicine_and_rehabilitation               NaN                  NaN
# radiation_oncology                                 NaN                  NaN
# rheumatology                                       NaN                  NaN
# specialist                                         NaN                  NaN
# sports_medicine                                    NaN                  NaN
#
#                                       ziprasidone_hcl  ziprasidone_mesylate
# specialty
# anesthesiology                                    NaN                   NaN
# family_practice                              0.041008              0.023812
# general_practice                                  NaN                   NaN
# geriatric_medicine                                NaN                   NaN
# hematology_oncology                               NaN                   NaN
# infectious_disease                                NaN                   NaN
# internal_medicine                            0.034708                   NaN
# interventional_pain_management                    NaN                   NaN
# medical_oncology                                  NaN                   NaN
# nephrology                                        NaN                   NaN
# neurology                                         NaN                   NaN
# nurse_practitioner                          -0.038647                   NaN
# osteopathic_manipulative_medicine                 NaN                   NaN
# pain_management                                   NaN                   NaN
# pediatric_medicine                                NaN                   NaN
# physical_medicine_and_rehabilitation              NaN                   NaN
# radiation_oncology                                NaN                   NaN
# rheumatology                                      NaN                   NaN
# specialist                                        NaN                   NaN
# sports_medicine                                   NaN                   NaN

# %%
others_names = drug_name_dict['others'] + ['op_longer', 'specialty']
others = eda_df.loc[:, others_names]
others = others.dropna(axis=1)

others = others.loc[others['specialty'].isin(top40), :]
others_corr = others.groupby('specialty').corrwith(others['op_longer'])
others_corr = others_corr.dropna(how='all', axis=1)
others_corr = others_corr.drop('op_longer', 1)

# %%
others_corr.mean(axis=0).sort_values(ascending=False)
# Out:
# gabapentin                        0.409202
# omeprazole                        0.368022
# metformin_hcl                     0.357480
# alprazolam                        0.318405
# furosemide                        0.315227
# levothyroxine_sodium              0.307131
# hydrochlorothiazide               0.304344
# tamsulosin_hcl                    0.302572
# meloxicam                         0.299456
# amlodipine_besylate               0.287176
# lisinopril                        0.284413
# pregabalin                        0.282526
# diazepam                          0.277529
# potassium_chloride                0.271198
# carvedilol                        0.270035
# glimepiride                       0.267902
# metoprolol_tartrate               0.266462
# lorazepam                         0.264460
# ibuprofen                         0.262256
# atorvastatin_calcium              0.262010
# atenolol                          0.259558
# albuterol_sulfate                 0.258481
# pravastatin_sodium                0.258392
# clopidogrel_bisulfate             0.245033
# glipizide                         0.243675
# citalopram_hydrobromide           0.243302
# losartan_potassium                0.243166
# metoprolol_succinate              0.242227
# sertraline_hcl                    0.237599
# allopurinol                       0.237301
# pantoprazole_sodium               0.236173
# lisinopril_hydrochlorothiazide    0.230720
# duloxetine_hcl                    0.225508
# spironolactone                    0.224095
# mesalamine                        0.222584
# warfarin_sodium                   0.219448
# donepezil_hcl                     0.218010
# lovastatin                        0.214957
# alendronate_sodium                0.206136
# azithromycin                      0.204458
# triamterene_hydrochlorothiazid    0.204039
# prednisone                        0.203745
# ciprofloxacin_hcl                 0.200927
# trazodone_hcl                     0.199099
# losartan_hydrochlorothiazide      0.198576
# celecoxib                         0.198432
# fluticasone_propionate            0.197663
# clonazepam                        0.195815
# ranitidine_hcl                    0.192157
# clotrimazole_betamethasone_dip    0.192016
# fenofibrate_micronized            0.190282
# fluoxetine_hcl                    0.188226
# naproxen                          0.187773
# benazepril_hcl                    0.187111
# temazepam                         0.182330
# clonidine_hcl                     0.180773
# insulin_glargine_hum.rec.anlog    0.174179
# fluticasone_salmeterol            0.167588
# aliskiren_hemifumarate            0.166116
# nystatin                          0.164005
# rosuvastatin_calcium              0.162939
# esomeprazole_magnesium            0.161868
# terazosin_hcl                     0.160536
# triamcinolone_acetonide           0.157701
# diclofenac_sodium                 0.156830
# topiramate                        0.156667
# umeclidinium_brm_vilanterol_tr    0.156419
# escitalopram_oxalate              0.152264
# fluconazole                       0.150844
# mirtazapine                       0.148794
# valsartan_hydrochlorothiazide     0.146460
# dicyclomine_hcl                   0.144636
# isosorbide_mononitrate            0.143512
# zoster_vaccine_live_pf            0.138983
# loperamide_hcl                    0.138283
# gemfibrozil                       0.134570
# propranolol_hcl                   0.132951
# pioglitazone_hcl                  0.132560
# methylprednisolone                0.130559
# bupropion_hcl                     0.129382
# pen_needle_diabetic               0.129178
# metronidazole                     0.128826
# ipratropium_albuterol_sulfate     0.126349
# enalapril_maleate                 0.125301
# finasteride                       0.124751
# pramipexole_di_hcl                0.123210
# ondansetron_hcl                   0.122943
# nitroglycerin                     0.121475
# paroxetine_hcl                    0.119772
# memantine_hcl                     0.119288
# dexlansoprazole                   0.117296
# gentamicin_sulfate                0.114389
# pyridostigmine_bromide            0.113318
# insulin_detemir                   0.113185
# buspirone_hcl                     0.111331
# verapamil_hcl                     0.108953
# prasugrel_hcl                     0.108314
# ammonium_lactate                  0.107905
# colchicine                        0.107557
# amlodipine_besylate_benazepril    0.106708
# ezetimibe                         0.105896
# sumatriptan_succinate             0.104322
# misoprostol                       0.104010
# syring_w_ndl_disp_insul_0.5_ml    0.102994
# ramipril                          0.102981
# olmesartan_medoxomil              0.102604
# phenytoin_sodium_extended         0.100905
# sucralfate                        0.100127
# lubiprostone                      0.099163
# polyethylene_glycol_3350          0.098862
# famotidine                        0.098311
# valsartan                         0.095076
# nifedipine                        0.094170
# nebivolol_hcl                     0.091785
# venlafaxine_hcl                   0.091197
# chlorthalidone                    0.090680
# lansoprazole                      0.090429
# metolazone                        0.089397
# clobetasol_propionate             0.089041
# fluticasone_vilanterol            0.088758
# lidocaine_hcl                     0.085445
# hydralazine_hcl                   0.082823
# primidone                         0.082639
# solifenacin_succinate             0.082110
# doxycycline_monohydrate           0.081812
# methylphenidate_hcl               0.076169
# omega_3_acid_ethyl_esters         0.074976
# insulin_lispro                    0.074757
# dutasteride                       0.074354
# exemestane                        0.073858
# acyclovir                         0.073776
# linagliptin                       0.072701
# ondansetron                       0.070462
# lactulose                         0.070302
# cholestyramine_(with_sugar)       0.070255
# sitagliptin_phos_metformin_hcl    0.068848
# carbidopa_levodopa                0.068148
# hydrocortisone                    0.067977
# nabumetone                        0.067584
# lipase_protease_amylase           0.063553
# irbesartan                        0.063483
# bethanechol_chloride              0.063477
# carbamazepine                     0.062225
# sulfacetamide_sodium              0.059474
# olmesartan_hydrochlorothiazide    0.055679
# oxaprozin                         0.054560
# estradiol                         0.054095
# alcohol_antiseptic_pads           0.053880
# insulin_aspart                    0.051906
# insulin_aspart_protam_&_aspart    0.051855
# desoximetasone                    0.051467
# neomycin_polymyxin_b_sulf_hc      0.050895
# testosterone_cypionate            0.050715
# raloxifene_hcl                    0.050026
# saxagliptin_hcl                   0.048391
# irbesartan_hydrochlorothiazide    0.046785
# sotalol_hcl                       0.046029
# diltiazem_hcl                     0.044347
# spironolact_hydrochlorothiazid    0.041728
# valproic_acid_(as_sodium_salt)    0.040524
# medroxyprogesterone_acetate       0.037917
# mupirocin                         0.036688
# theophylline_anhydrous            0.035594
# sodium_polystyrene_sulfonate      0.034993
# valacyclovir_hcl                  0.034803
# liothyronine_sodium               0.032403
# famciclovir                       0.032293
# azelastine_hcl                    0.032161
# divalproex_sodium                 0.032076
# dextroamphetamine_amphetamine     0.030046
# liraglutide                       0.027071
# quinapril_hcl                     0.026830
# lidocaine_prilocaine              0.026277
# clonidine                         0.024974
# econazole_nitrate                 0.024798
# ibandronate_sodium                0.024796
# ciclopirox                        0.024003
# budesonide                        0.023408
# bumetanide                        0.022911
# phenazopyridine_hcl               0.021811
# torsemide                         0.020658
# acarbose                          0.020334
# ivermectin                        0.020030
# niacin                            0.019974
# beclomethasone_dipropionate       0.019048
# calcipotriene                     0.018652
# peg_3350_na_sulf_bicarb_cl_kcl    0.018552
# diph_pertuss(acell)_tet_vac_pf    0.017952
# nortriptyline_hcl                 0.017237
# febuxostat                        0.017150
# doxepin_hcl                       0.015789
# fluocinonide                      0.014916
# pitavastatin_calcium              0.014666
# rivaroxaban                       0.014106
# amiodarone_hcl                    0.013764
# atenolol_chlorthalidone           0.013560
# glipizide_metformin_hcl           0.013059
# quinapril_hydrochlorothiazide     0.010655
# amlodipine_valsartan              0.007746
# rivastigmine_tartrate             0.007514
# pen_needle_diabetic_safety        0.007492
# apixaban                          0.007299
# calcitriol                        0.006420
# calcitonin_salmon_synthetic       0.006127
# fludrocortisone_acetate           0.005889
# brimonidine_tartrate              0.003714
# dapagliflozin_propanediol         0.003466
# prochlorperazine_maleate          0.002049
# insulin_regular_human             0.002019
# insulin_lispro_protamin_lispro    0.001568
# oseltamivir_phosphate            -0.000133
# piroxicam                        -0.000598
# prednisolone_acetate             -0.000644
# desloratadine                    -0.001005
# bisoprolol_fumarate              -0.002114
# polymyxin_b_sulf_trimethoprim    -0.002427
# syring_w_ndl_disp_insul_0.3_ml   -0.003053
# labetalol_hcl                    -0.003658
# galantamine_hbr                  -0.003842
# ipratropium_bromide              -0.004469
# progesterone_micronized          -0.005588
# alfuzosin_hcl                    -0.006009
# lamotrigine                      -0.006726
# levalbuterol_tartrate            -0.007403
# efinaconazole                    -0.007630
# clindamycin_phosphate            -0.008323
# ezetimibe_simvastatin            -0.008384
# dorzolamide_hcl_timolol_maleat   -0.009630
# fluvoxamine_maleate              -0.009810
# timolol_maleate                  -0.010309
# chlorhexidine_gluconate          -0.012246
# mirabegron                       -0.012969
# fluocinonide_emollient_base      -0.014402
# dronedarone_hcl                  -0.015685
# tacrolimus                       -0.015992
# cimetidine                       -0.016815
# empagliflozin                    -0.016895
# epinephrine                      -0.016911
# dexamethasone                    -0.018363
# rotigotine                       -0.019318
# mometasone_formoterol            -0.020391
# moxifloxacin_hcl                 -0.023274
# tobramycin                       -0.023566
# insulin_nph_human_isophane       -0.025108
# aspirin_dipyridamole             -0.031714
# azelastine_fluticasone           -0.033516
# potassium_citrate                -0.035686
# enoxaparin_sodium                -0.041515
# lanthanum_carbonate              -0.049692
# valganciclovir_hcl               -0.051633
# pomalidomide                     -0.057065
# entacapone                       -0.070594
# dtype: float64

# %%
others_small = others_corr.dropna(thresh=len(others_corr) - 15, axis=1)
sorted_name = others_small.mean(axis=0).sort_values(ascending=False).index
sorted_spec = others_small.mean(axis=1).sort_values(ascending=False).index
others_small = others_small.loc[sorted_spec, :]
others_small = others_small.loc[:, sorted_name]

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(others_small.fillna(0), square=True, cbar=False, cmap=cmap)
plt.title('Heatmap of correlation to the label(op_longer)')
plt.xlabel('Drug names')
plt.ylabel('Specialty')
plt.show()
